# %% [markdown]
# EDA Y ETL DE DATOS POBLACIONALES PARA RESPALDAR ANÁLISIS

# %%
import pandas as pd

# %%
# Ruta del archivo Excel
archivo_excel = 'datos_poblacionales_bancom.xlsx'

# Cargar solo la primera hoja en un DataFrame
df = pd.read_excel(archivo_excel, sheet_name=0) 
df
# Out:
#                                           Data Source  \
# 0                                   Last Updated Date
# 1                                                 NaN
# 2                                        Country Name
# 3                                               Aruba
# 4                                           Argentina
# 5                                   Antigua y Barbuda
# 6                                             Bahamas
# 7                                              Belice
# 8                                            Bermudas
# 9                                             Bolivia
# 10                                             Brasil
# 11                                           Barbados
# 12                                              Chile
# 13                                           Colombia
# 14                                         Costa Rica
# 15                        Estados pequeños del Caribe
# ...

# %%
df = df.rename(columns= {'Data Source':'Country Name', 'Indicadores del desarrollo mundial' : 'Country Code', 'Unnamed: 2':'2018', 'Unnamed: 3':'2019','Unnamed: 4' :'2020','Unnamed: 5' :'2021','Unnamed: 6':'2022','Unnamed: 7':'2023'})
df.head()
# Out:
#         Country Name         Country Code        2018        2019        2020  \
# 0  Last Updated Date  2024-09-19 00:00:00         NaN         NaN         NaN
# 1                NaN                  NaN         NaN         NaN         NaN
# 2       Country Name         Country Code      2018.0      2019.0      2020.0
# 3              Aruba                  ABW    105962.0    106442.0    106585.0
# 4          Argentina                  ARG  44494502.0  44938712.0  45376763.0
#
#          2021        2022        2023  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# 1         NaN         NaN         NaN         NaN         NaN  ...
# 2      2021.0      2022.0      2023.0         NaN         NaN  ...
# 3    106537.0    106445.0    106277.0         NaN         NaN  ...
# 4  45808747.0  46234830.0  46654581.0         NaN         NaN  ...
#
#    Unnamed: 58  Unnamed: 59  Unnamed: 60  Unnamed: 61  Unnamed: 62  \
# ...

# %%
# Eliminar todas las columnas desde la columna 9 en adelante
df = df.drop(df.columns[8:], axis=1)
df
# Out:
#                                          Country Name         Country Code  \
# 0                                   Last Updated Date  2024-09-19 00:00:00
# 1                                                 NaN                  NaN
# 2                                        Country Name         Country Code
# 3                                               Aruba                  ABW
# 4                                           Argentina                  ARG
# 5                                   Antigua y Barbuda                  ATG
# 6                                             Bahamas                  BHS
# 7                                              Belice                  BLZ
# 8                                            Bermudas                  BMU
# 9                                             Bolivia                  BOL
# 10                                             Brasil                  BRA
# ...

# %%
# Eliminar las 3 primeras filas
df = df.drop(index=[0, 1, 2])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 3 to 47
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  45 non-null     object
#  1   Country Code  45 non-null     object
#  2   2018          45 non-null     float64
#  3   2019          45 non-null     float64
#  4   2020          45 non-null     float64
#  5   2021          45 non-null     float64
#  6   2022          45 non-null     float64
#  7   2023          45 non-null     float64
# dtypes: float64(6), object(2)
# memory usage: 2.9+ KB

# %%
pd.set_option('display.float_format', '{:.3f}'.format)

# %%
df.describe()
# Out:
#                2018          2019          2020          2021          2022  \
# count        45.000        45.000        45.000        45.000        45.000
# mean   41171527.289  41559186.178  41910101.711  42207530.889  42490779.356
# std   129060489.639 130287991.390 131389219.434 132319266.886 133196034.092
# min       30335.000     30610.000     30910.000     31122.000     31305.000
# 25%      107001.000    106669.000    106585.000    106537.000    106445.000
# 50%     3058106.000   3090374.000   3106185.000   3128519.000   3147057.000
# 75%    11606905.000  11777315.000  11936162.000  12079472.000  12224110.000
# max   639626265.000 645293844.000 650533026.000 654978670.000 659306928.000
#
#                2023
# count        45.000
# mean   42800056.844
# std   134144795.167
# min       31538.000
# 25%      106277.000
# 50%     3167738.000
# 75%    12388571.000
# max   664155299.000

# %% [markdown]
# BOXPLOT

# %%
# Seleccionar solo las columnas numéricas
columnas_numericas = df.select_dtypes(include='number')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_palette("pastel")

# Crear el boxplot para las columnas numéricas
plt.figure(figsize=(10, 6))
sns.boxplot(data=columnas_numericas)

# Título del gráfico
plt.title("Boxplot de columnas numéricas")

# Mostrar el gráfico
plt.show()
